# %%
from typing import List
from enum import Enum, auto
import random
import networkx as nx #Python library for working with graphs
from collections import deque #deque, Double Ended Queue
random.seed(0)

# %%
# Make percept a clean data container that the Environment can create and the Agent can read.
class Percept():
  time_step: int
  bump : bool
  breeze : bool
  stench : bool
  scream : bool
  glitter : bool
  reward : int
  done : bool

  def __init__(self, time_step: int, bump : bool, breeze : bool, stench : bool, scream : bool, glitter : bool, reward : int, done : bool):
    self.time_step = time_step
    self.bump = bump
    self.breeze = breeze
    self.stench = stench
    self.scream = scream
    self.glitter = glitter
    self.reward = reward
    self.done = done

  def __str__(self):
    return ( f"t={self.time_step} | "
     f"bump={self.bump}, breeze={self.breeze}, stench={self.stench}, scream={self.scream}, glitter={self.glitter} | "
     f"reward={self.reward} | "
     f"done={self.done}"
    )

# %%
# let's test the class
#perectTest=Percept(1,True,False,False,False,False,-11,False)
#print(perectTest)
#print(perectTest.bump)
#perectTest2=Percept(1,True,False,False,False,False,-11,True)
#print(perectTest2)

# %%
class Action(Enum):
  LEFT = auto()
  RIGHT = auto()
  FORWARD = auto()
  GRAB = auto()
  SHOOT = auto()
  CLIMB =  auto()

# %%
# Let's test Action
#list(Action)
#random.choice(list(Action))

# %%
class Orientation(Enum):
  E = auto()
  S = auto()
  W = auto()
  N = auto()

  def symbol(self)-> str:
    return self.name

  def turn_right(self)->'Orientation':
    if self == Orientation.E:
      return Orientation.S
    if self == Orientation.S:
      return Orientation.W
    if self == Orientation.W:
      return Orientation.N
    else:
      return Orientation.E

  def turn_left(self)->'Orientation':
    if self == Orientation.E:
      return Orientation.N
    if self == Orientation.N:
      return Orientation.W
    if self == Orientation.W:
      return Orientation.S
    else:
      return Orientation.E

# %%
# Let's test orientation
# Orientation.N.symbol()
# print(Orientation.E.turn_right())
# print(Orientation.E.turn_left())

# %%
class NaiveAgent():
  def choose_action(self):
    return random.choice(list(Action))

  def run(self):
    env = Environment() # this is creating an object of env from Environment Class
    cumulative_reward = 0
    percept = env.init(0.2, False)
    while not percept.done:
      env.visualize()
      print("Percept:", percept)
      action = self.choose_action()
      print("Action:", action)
      percept = env.step(action)
      cumulative_reward += percept.reward
    env.visualize()
    print("Percept:", percept)
    print('Cumulative reward:', cumulative_reward)

# %%
# Let's test NaiveAgent class
# n = NaiveAgent()
# print(n.choose_action())

# %%
class Location():
  x: int
  y: int

  def __init__(self, x: int, y: int):
    self.x = x
    self.y = y

  def __str__(self):
    return f'({self.x},{self.y})'

  def is_left_of(self, location: 'Location')-> bool:
    return self.x == location.x - 1 and self.y == location.y

  def is_right_of(self, location: 'Location')->bool:
    return self.x == location.x + 1 and self.y == location.y

  def is_above(self, location: 'Location')->bool:
    return self.x == location.x and self.y == location.y + 1

  def is_below(self, location: 'Location')->bool:
    return self.x == location.x and self.y == location.y - 1

  def is_location(self, location: 'Location')->bool:
    return self.x == location.x and self.y == location.y

  def at_left_edge(self)->bool:
    return self.x == 0

  def at_right_edge(self)->bool:
    return self.x == 3

  def at_bottom_edge(self)->bool:
    return self.y == 0

  def at_top_edge(self)->bool:
    return self.y == 3

  def neighbours(self)->list('location'):
    neighbours = []
    if not self.at_left_edge():
      neighbours.append(Location(self.x-1, self.y))
    if not self.at_right_edge():
      neighbours.append(Location(self.x+1, self.y))
    if not self.at_bottom_edge():
      neighbours.append(Location(self.x, self.y-1))
    if not self.at_top_edge():
      neighbours.append(Location(self.x, self.y+1))
    return neighbours
  def set_to(self, location:'Location'):
    self.x == location.x
    self.y == location.y
  def forward(self, orientation)->bool: #return True if bumped a wall
    if orientation == Orientation.E:
      if self.at_right_edge():
        return True
      self.x +=1
      return False

    if orientation == Orientation.S:
      if self.at_bottom_edge():
        return True
      self.y -=1
      return False

    if orientation == Orientation.W:
      if self.at_left_edge():
        return True
      self.x -=1
      return False

    # orientation == Orientation.N:
    if self.at_top_edge():
      return True
    self.y +=1
    return False

  @staticmethod
  def from_linear(n:int)->'location':
    x = n % 4
    y = n // 4
    return Location(x,y)

  def to_linear(self)->int:
    return self.x + self.y * 4

  @staticmethod
  def random()->'location':
    return Location(random.randint(0,3),random.randint(0,3))

# %%
# Let's test Location class
#print(Location(1,2))
#print(Location(1,2).is_left_of(Location(2,2)))  # True
#for n in Location(0,0).neighbours():
#  print(n)
#print(Location(0,0).neighbours())               # should be [(1,0), (0,1)] in some order
#loc = Location(3,0)
#print(loc.forward(Orientation.E), loc)          # True (bump), (3,0) unchanged
#loc2 = Location(1,1)
#print(loc2.forward(Orientation.N), loc2)        # False, now (1,2)

# %%
# Let's test Location class
# print(Location.random())
# print(Location.from_linear(15))
# print(Location(0,1).to_linear())

# %%
class Environment():
  wumpus_location: Location
  wumpus_alive: bool
  agent_location: Location
  agent_orientation: Orientation
  agent_has_arrow: bool
  agent_has_gold: bool
  game_over: bool
  gold_location: Location
  pit_locations: List[Location]
  time_step: int
  pit_prob: float
  allow_climb_without_gold: bool

  def init(self, pit_prob: float, allow_climb_without_gold: bool):
    self.allow_climb_without_gold=allow_climb_without_gold
    self.pit_prob=pit_prob
    self.agent_location=Location(0,0)
    self.agent_orientation=Orientation.E
    self.agent_has_arrow=True
    self.agent_has_gold=False
    self.game_over=False
    self.time_step=0

    self.make_wumpus()
    self.make_gold()
    self.make_pits(pit_prob)

    return Percept(time_step=0,
                   bump= False,
                   breeze=self.is_breeze(),
                   stench=self.is_stench(),
                   scream=False,
                   glitter=self.is_glitter(),
                   reward=0,
                   done=self.game_over)

  def make_wumpus(self):
    self.wumpus_alive = True
    while True:
      loc = Location.random()
      if not loc.is_location(Location(0,0)):
        self.wumpus_location = loc
        return

  def make_gold(self):
    while True:
      loc = Location.random()
      if not loc.is_location(Location(0,0)):
        self.gold_location = loc
        return

  def make_pits(self, pit_prob):
    self.pit_locations = []
    for n in range(16):
      loc = Location.from_linear(n)
      if loc.is_location(Location(0,0)):
        continue
      if random.random() < pit_prob:
        self.pit_locations.append(loc)
    return

  def is_pit_at(self, location)->bool:
    for p in self.pit_locations:
      if p.is_location(location):
        return True
    return False

  def is_wumpus_at(self, location)->bool:
    return self.wumpus_location.is_location(location)

  def is_agent_at(self, location)->bool:
    return self.agent_location.is_location(location)

  def is_gold_at(self, location)->bool:
    if self.agent_has_gold:
      return self.agent_location.is_location(location)
    return self.gold_location.is_location(location)

  def is_pit_adjacent_to_agent(self)->bool:
    neighbours = self.agent_location.neighbours()
    for p in self.pit_locations:
      for n in neighbours:
        if p.is_location(n):
          return True
    return False

  def is_wumpus_adjacent_to_agent(self)->bool:
    neighbours = self.agent_location.neighbours()
    for n in neighbours:
      if self.wumpus_location.is_location(n):
        return True
    return False

  def is_agent_at_hazard(self)->bool:
        return any(self.agent_location.is_location(p) for p in self.pit_locations) or (self.wumpus_location.is_location(self.agent_location) and self.wumpus_alive)

  def is_glitter(self)->bool:
        return self.is_gold_at(self.agent_location)

  def is_breeze(self)->bool:
        return self.is_pit_adjacent_to_agent() or any(p.is_location(self.agent_location) for p in self.pit_locations)

  def is_stench(self)->bool:
        return self.is_wumpus_adjacent_to_agent() or self.agent_location.is_location(self.wumpus_location)


  def wumpus_in_line_of_fire(self)->bool:
    # return true if the wumpus is a cell the arrow would pass through if fired
    ax, ay = self.agent_location.x, self.agent_location.y
    wx, wy = self.wumpus_location.x, self.wumpus_location.y

    if self.agent_orientation == Orientation.E:
      return wx > ax and wy == ay

    if self.agent_orientation == Orientation.S:
      return wx == ax and wy < ay

    if self.agent_orientation == Orientation.W:
      return wx < ax and wy == ay

    return wx == ax and wy > ay

  def kill_attempt(self)->bool:
    if self.wumpus_in_line_of_fire() and self.wumpus_alive:
      self.wumpus_alive = False
      return True
    return False

  def step(self, action: Action) -> Percept:
    if self.game_over:
        return Percept(
            time_step=self.time_step,
            bump=False,
            breeze=self.is_breeze(),
            stench=self.is_stench(),
            scream=False,
            glitter=self.is_glitter(),
            reward=0,
            done=True
        )

    self.time_step += 1
    reward = -1
    bump = False
    scream = False

    if action == Action.LEFT:
        self.agent_orientation = self.agent_orientation.turn_left()

    elif action == Action.RIGHT:
        self.agent_orientation = self.agent_orientation.turn_right()

    elif action == Action.FORWARD:
        bump = self.agent_location.forward(self.agent_orientation)

    elif action == Action.GRAB:
        if self.agent_location.is_location(self.gold_location):
            self.agent_has_gold = True

    elif action == Action.SHOOT:
        if self.agent_has_arrow:
            self.agent_has_arrow = False
            reward -= 10
            scream = self.kill_attempt()

    elif action == Action.CLIMB:
        at_start = self.agent_location.is_location(Location(0, 0))
        if at_start:
            if self.agent_has_gold:
                reward += 1000
                self.game_over = True
            elif self.allow_climb_without_gold:
                self.game_over = True

    if not self.game_over and self.is_agent_at_hazard():
        reward -= 1000
        self.game_over = True

    return Percept(
        time_step=self.time_step,
        bump=bump,
        breeze=self.is_breeze(),
        stench=self.is_stench(),
        scream=scream,
        glitter=self.is_glitter(),
        reward=reward,
        done=self.game_over
    )
  # Visualize the game state
  def visualize(self):
      for y in range(3, -1, -1):
          line = '|'
          for x in range(0, 4):
              loc = Location(x, y)
              cell_symbols = [' ', ' ', ' ', ' ']
              if self.is_agent_at(loc): cell_symbols[0] = self.agent_orientation.symbol()
              if self.is_pit_at(loc): cell_symbols[1] = 'P'
              if self.is_wumpus_at(loc):
                  if self.wumpus_alive:
                      cell_symbols[2] = 'W'
                  else:
                      cell_symbols[2] = 'w'
              if self.is_gold_at(loc): cell_symbols[3] = 'G'
              for char in cell_symbols: line += char
              line += '|'
          print(line)

# %%
# Let's test the Environment class
#nv = Environment()
#p = env.init(0.0, True)
#env.visualize()
#print(p)
#p = env.step(Action.SHOOT)
#print(p.reward)
#p2 = env.step(Action.SHOOT)
#print(p2.reward)
#env.agent_location = Location(0,0)
#env.agent_orientation = Orientation.W
#p = env.step(Action.FORWARD)
#print(p.bump, env.agent_location)
#env = Environment()
#env.init(0.0, True)
#env.agent_location = Location(1,0)
#p = env.step(Action.CLIMB)
#print(p.done)  # should be False (not at start)

# %% [markdown]
# Let's start with assignment 2.

# %%
class MovePlanningAgent():
  def __init__(self):
    self.has_gold=False
    self.loc = Location(0,0)
    self.ori = Orientation.E
    self.visited = set()
    self.graph = nx.DiGraph() #Directed Graph, meaning direction matters
    self.plan = [] #List of planned actions to execute after grabbing the gold.

  #Helper representing graph nodes(states)
  def state(self, x, y, ori):
    return (x,y,ori)

  def add_cell(self,x,y):
    #1) add the 4 orientation nodes
    for ori in [Orientation.N, Orientation.E, Orientation.S, Orientation.W]:
      self.graph.add_node(self.state(x,y,ori))
    #2) add turning edges (stay in same cell)
    for ori in [Orientation.N, Orientation.E, Orientation.S, Orientation.W]:
      self.graph.add_edge(self.state(x,y,ori),self.state(x,y,ori.turn_left()),action=Action.LEFT)
      self.graph.add_edge(self.state(x,y,ori),self.state(x,y,ori.turn_right()),action=Action.RIGHT)

  #Add a helper to compute the forward neighbor
  def forward_cell(self, x, y, ori):
    if ori == Orientation.N:
        return (x, y+1)
    elif ori == Orientation.E:
        return (x+1, y)
    elif ori == Orientation.S:
        return (x, y-1)
    elif ori == Orientation.W:
        return (x-1, y)

  #Add a function that adds forward edges for one cell
  def add_forward_edge(self,x,y,ori):
    nx,ny= self.forward_cell(x,y,ori) #returns a tuple
    if (nx,ny) in self.visited:
        self.graph.add_edge(self.state(x,y,ori),self.state(nx,ny,ori),action=Action.FORWARD)

  def add_forward_edges(self,x,y):
    for ori in [Orientation.N, Orientation.E, Orientation.S, Orientation.W]:
      self.add_forward_edge(x,y,ori)

  def choose_action(self, percept: Percept):
    #if we have a gold and we are at the goal location we just need to climb
    if self.has_gold and (self.loc.x, self.loc.y)==(0,0):
      return Action.CLIMB

    #if we already have a plan we don't go with random
    if self.plan:
      return self.plan.pop(0)

    #if percept is glitter -> grab
    if percept.glitter and not self.has_gold:
      self.has_gold=True
      return Action.GRAB

    #if self.plan is empty, we are not in the start and we already grabbed the gold, we need to fill in the self.plan
    if self.has_gold and not self.plan and (self.loc.x, self.loc.y)!=(0,0):
      self.plan = self.bfs_actions_to_start()
      print("PLANNING RETURN:", self.plan)
      if self.plan:
        return self.plan.pop(0)

    #ow choose another action
    return random.choice([Action.LEFT, Action.RIGHT, Action.FORWARD, Action.SHOOT])

  def update_state(self, action, new_percept):
    if action == Action.LEFT:
        self.ori = self.ori.turn_left()

    elif action == Action.RIGHT:
        self.ori = self.ori.turn_right()

    elif action == Action.FORWARD:
        if not new_percept.bump:
          if self.ori == Orientation.E:
            self.loc = Location(self.loc.x+1,self.loc.y)

          elif self.ori == Orientation.S:
            self.loc = Location(self.loc.x, self.loc.y-1)

          elif self.ori == Orientation.W:
            self.loc = Location(self.loc.x-1, self.loc.y)

          elif self.ori == Orientation.N:
            self.loc = Location(self.loc.x, self.loc.y+1)

  def bfs_actions_to_start(self):
    start_state = self.state(self.loc.x,self.loc.y,self.ori)

    goals = {
        (0,0,Orientation.N),
        (0,0,Orientation.E),
        (0,0,Orientation.S),
        (0,0,Orientation.W)
    }

    q = deque([start_state])

    parent = {start_state:None}
    parent_action = {start_state:None}

    while q:
      s = q.popleft()

      if s in goals:
        actions = []

        while parent[s] is not None:
          actions.append(parent_action[s])
          s=parent[s]

        actions.reverse()
        return actions

      for nxt in self.graph.successors(s):
        if nxt not in parent:
          parent[nxt] = s
          parent_action[nxt]= self.graph[s][nxt]["action"]
          q.append(nxt)

    return []

  def run(self):
    env = Environment() # this is creating an object of env from Environment Class
    cumulative_reward = 0
    percept = env.init(0.2, False)
    #percept = env.init(0.0, False)
    self.visited.add((self.loc.x,self.loc.y))
    self.add_cell(self.loc.x,self.loc.y)
    self.add_forward_edges(self.loc.x,self.loc.y)

    while not percept.done:
      env.visualize()
      print("Percept:", percept)
      print("Has Gold:", self.has_gold)
      action = self.choose_action(percept)
      print("Action:", action)
      old = (self.loc.x,self.loc.y)
      percept = env.step(action)
      self.update_state(action,percept)
      new = (self.loc.x,self.loc.y)
      print(new,self.ori,percept.bump)
      entered_new_cell = (old !=new ) and (not percept.done)
      if entered_new_cell:
        self.visited.add(new)
        self.add_cell(new[0],new[1])
        self.add_forward_edges(new[0],new[1])
        x, y= new
        for (vx,vy) in self.visited:
          if abs(vx-x) + abs(vy-y) == 1:
            self.add_forward_edges(vx,vy)
      cumulative_reward += percept.reward

    env.visualize()
    print("Visited count:", len(self.visited))
    print("Graph nodes:", self.graph.number_of_nodes())
    print("Graph edges:", self.graph.number_of_edges())
    print("Percept:", percept)
    print('Cumulative reward:', cumulative_reward)

# %%
#let's run some tests
#agent = MovePlanningAgent()
#agent.run()
# Out:
# Streaming output truncated to the last 5000 lines.
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004048 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004049 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004050 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004051 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004052 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004053 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004054 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004055 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004056 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004057 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004058 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004059 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004060 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004061 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004062 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004063 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004064 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004065 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004066 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004067 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004068 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004069 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004070 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004071 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004072 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004073 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004074 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004075 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004076 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004077 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004078 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004079 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004080 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004081 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004082 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004083 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004084 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004085 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004086 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004087 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004088 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004089 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004090 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004091 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004092 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004093 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004094 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004095 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004096 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004097 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004098 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004099 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004100 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004101 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004102 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004103 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004104 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004105 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004106 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004107 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004108 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004109 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004110 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004111 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004112 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004113 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004114 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004115 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004116 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004117 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004118 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004119 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004120 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004121 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004122 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004123 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004124 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004125 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004126 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004127 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004128 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004129 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004130 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004131 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004132 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004133 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004134 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004135 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004136 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004137 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004138 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004139 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004140 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004141 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004142 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004143 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004144 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004145 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004146 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004147 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004148 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004149 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004150 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004151 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004152 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004153 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004154 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004155 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004156 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004157 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004158 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004159 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004160 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004161 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004162 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004163 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004164 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004165 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004166 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004167 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004168 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004169 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004170 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004171 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004172 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004173 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004174 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004175 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004176 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004177 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004178 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004179 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004180 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004181 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004182 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004183 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004184 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004185 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004186 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004187 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004188 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004189 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004190 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004191 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004192 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004193 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004194 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004195 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004196 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004197 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004198 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004199 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004200 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004201 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004202 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004203 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004204 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004205 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004206 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004207 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004208 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004209 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004210 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004211 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004212 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004213 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004214 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004215 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004216 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004217 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004218 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004219 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004220 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004221 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004222 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004223 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004224 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004225 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# ...
# |E  G|    |    |    |
# Percept: t=2004613 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004614 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004615 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004616 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004617 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004618 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004619 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004620 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004621 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004622 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004623 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004624 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (1, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |E  G|    |    |
# Percept: t=2004625 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (1, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |N  G|    |    |
# Percept: t=2004626 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (1, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |    |W  G|    |    |
# Percept: t=2004627 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004628 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004629 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004630 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004631 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004632 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004633 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.W True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004634 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004635 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004636 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004637 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004638 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004639 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004640 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004641 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 1) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |N  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004642 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# PLANNING RETURN: [<Action.LEFT: 1>, <Action.LEFT: 1>, <Action.FORWARD: 3>]
# Action: Action.LEFT
# (0, 1) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |W  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004643 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 1) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |S  G|    |    |    |
# |    |    |    |    |
# Percept: t=2004644 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004645 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004646 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004647 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004648 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004649 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004650 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.FORWARD
# (0, 0) Orientation.S True
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004651 | bump=True, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004652 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004653 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004654 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004655 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004656 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004657 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004658 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004659 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004660 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.S False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |S  G|    |    |    |
# Percept: t=2004661 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.E False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |E  G|    |    |    |
# Percept: t=2004662 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004663 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004664 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004665 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.RIGHT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004666 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.SHOOT
# (0, 0) Orientation.N False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |N  G|    |    |    |
# Percept: t=2004667 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# Has Gold: True
# Action: Action.LEFT
# (0, 0) Orientation.W False
# |    |    |    |  W |
# |    | P  | P  | P  |
# |    |    |    |    |
# |W  G|    |    |    |
# Percept: t=2004668 | bump=False, breeze=False, stench=False, scream=False, glitter=True | reward=-1 | done=False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_499/2379689622.py in <cell line: 0>()
#       1 #let's run some tests
#       2 agent = MovePlanningAgent()
# ----> 3 agent.run()
#
# /tmp/ipykernel_499/395307503.py in run(self)
#     131       env.visualize()
#     132       print("Percept:", percept)
# --> 133       print("Has Gold:", self.has_gold)
#     134       action = self.choose_action(percept)
#     135       print("Action:", action)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py in write(self, string)
#     548         else:
#     549
# --> 550             is_child = not self._is_master_process()
#     551             # only touch the buffer in the IO thread to avoid races
#     552             with self._buffer_lock:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     436
#     437     def _is_master_process(self):
# --> 438         return os.getpid() == self._master_pid
#     439
#     440     def set_parent(self, parent):
#
# KeyboardInterrupt:
